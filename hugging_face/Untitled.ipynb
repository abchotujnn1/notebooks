# %%
import numpy as np
from scipy import stats as st
import seaborn as sns

# %%
x= [62, 65, 59, 68, 70, 66, 71, 63, 64, 72, 69, 67, 68, 66, 64, 70, 65, 63, 61, 67, 68, 62, 66, 70, 73]

# %%
len(x)
# Out:
# 25

# %%
np.mean(x)
# Out:
# 66.36

# %%
np.sum(x)
# Out:
# 1659

# %%
np.median(x)
# Out:
# 66.0

# %%
st.mode(x)
# Out:
# ModeResult(mode=66, count=3)

# %%
st.skew(x)
# Out:
# -0.06982010164109378

# %%
sns.kdeplot(x)
# Out:
# <Axes: ylabel='Density'>
